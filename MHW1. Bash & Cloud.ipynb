# %% [markdown]
# # Мини задание 1
#
# [**Задание 1.**] (**5 баллов**) В рамках задания необходимо развернуть необходимую инфраструктуру в Яндекс.Облаке, предобработать данные и залить их в хранилище.
#
# Кластер и прокси машину поднимаете по материалом семинара 1 и его видеозаписи. За непонятными моментами и вопросами по теме можно обратиться в тг топик чата курса.
#
# Работать будет с датасетом из соревнования на Kaggle - https://www.kaggle.com/c/avito-context-ad-clicks . Для работы с ним потребуется аккаунт на Kaggle - заведите его, если его еще нет. Возможно, у вас будут проблемы с верификацией телефонного номера. Узнайте у одногруппников, как они решали эту проблему, если кто-то из них заводил аккаунты на kaggle в рамках работы на других курсах.
#
# # О данных в датасете
# В файле `VisitsStream.tsv` содержится информация о посещениях пользователями сайта в хронологическом порядке. Необходимо взять первые 1 000 000 записей из этой таблицы и подсчитать для них топ-10 пользователей (userId) по числу посещений. Количество этих посещений также должно быть отображено в результате. Все этапы -  загрузка, преобразования и выгрузка данных - необходимо произвести с использованием Bash (не скрипты на Python).
#
# Чтобы скачать файл, воспользуйтесь `kaggle CLI` - https://github.com/Kaggle/kaggle-api. Нужно немного помучиться с тем, где и как вам надо разместить файл с токеном для работы api, но эта работа даст вам удобный инструмент, чтобы стягивать датасеты с каггла через скрипт.
#
# Полученный файл необходимо загрузить в облачное хранилище (object storage) таким образом, чтобы к нему был публичный доступ извне. Ссылка на этот файл должна также присутствовать в сдаваемом решении.
#
# Пример файла с результатом
# ```
#    5213 45743577
#    2617 764540
#     794 4353457
#     323 3093437
#     124 4293412
#     78 773445
#     56 3665544
#     43 323413
#     36 2632454
#     32 1124347
# ```
#
# [**Задание 2.**] (**5 Баллов**) Поработайте с файлом `AdsInfo.tsv` на предмет решения следующей задачи.
#
# Используя классический Hadoop MapReduce необходимо посчитать сумму стоимостей рекламных объявлений (Price) для каждой категории (CategoryID) в отедльности.
#
# Пример файла с результатом: выведены все категории, в порядке возрастания их id
# ```
#     53 101000000
#     54 10200000
#     57 148823456
#     59 5678905
#     60 1234455
#     250001 1234566
#     250004 1354542
#     250005 12321345
#     250006 12323213
#     500001 1312313
# ```
# Результат это задачи также выгрузите в итоговый файл и разместите его в облачном хранилище.
#
# В качестве выполненного домашнего задания пришлите Jupyter Notebook в формате `.ipynb` (ссылку для сдачи смотрите на Wiki). В названии файла укажите свое имя и фамилию **на русском**. В этом ноутбуке должны быть отображены
#
# 1. Скрипт Bash, который вы запускали на мастер-машине для обработки данных и выгрузки их в облако
# 2. Ссылка на выгруженный файл в вашем облаке
# 3. Реализованная map reduce задача с использованием нужных данных на входе, собранные вами для задачи питоновские скрипты
#
# **Важно!** Не удаляйте облачное хранилище до конца проверки домашнего задания! Файлы будут скачаны проверяющим и если до них не будет доступа, то это отразится на оценке за задание.
#
# **Важно!** Не палите свои пароли для kaggle (или любые другие пароли тоже). Мы конечно не собираемся ничего с ними делать, но полезно потренировать свои навыки информационной безопасности.
